# %% [markdown]
# <a href="https://colab.research.google.com/github/vedsub/hftransf/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tok_text = "Vedant's the  greatest creation of the God".split()
print(tok_text)
# Out:
# ["Vedant's", 'the', 'greatest', 'creation', 'of', 'the', 'God']

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
tokenizer("Transformer is a crazy concept")
# Out:
# {'input_ids': [101, 13809, 23763, 1110, 170, 4523, 3400, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}

# %%
#encoding

# %%
from transformers import AutoTokenizer
tokenizer  = AutoTokenizer.from_pretrained("bert-base-cased")
seq = "Ronaldo  is the greatest"
tokens = tokenizer.tokenize(seq) #tokenize() is the main function here
print(tokens)
# Out:
# ['Ronald', '##o', 'is', 'the', 'greatest']

# %%
ids = tokenizer.convert_tokens_to_ids(tokens)
print(ids)
# Out:
# [8565, 1186, 1110, 1103, 4459]

# %%
#decoding

# %%
decoded_string = tokenizer.decode([8565, 1186, 1110, 1103, 4459])
print(decoded_string)
# Out:
# Ronaldo is the greatest

# %%
import torch
from transformers import AutoTokenizer , AutoModelForSequenceClassification
checkpoint = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint)

sequence = "I am the greatest puss"

tokens = tokenizer.tokenize(sequence)
ids = tokenizer.convert_tokens_to_ids(tokens)
input_ids = torch.tensor([ids])
print("Input IDs:", input_ids)

output = model(input_ids)
print("Logits:", output.logits)
# Out:
# Input IDs: tensor([[ 1045,  2572,  1996,  4602, 16405,  4757]])
# Logits: tensor([[-2.5259,  2.8390]], grad_fn=<AddmmBackward0>)

# %%
model = AutoModelForSequenceClassification.from_pretrained(checkpoint)

sequence1_ids = [[200, 200, 200]]
sequence2_ids = [[200, 200]]
batched_ids = [
    [200, 200, 200],
    [200, 200, tokenizer.pad_token_id],
]

print(model(torch.tensor(sequence1_ids)).logits)
print(model(torch.tensor(sequence2_ids)).logits)
print(model(torch.tensor(batched_ids)).logits)
# Out:
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# tensor([[ 1.5694, -1.3895]], grad_fn=<AddmmBackward0>)
# tensor([[ 0.5803, -0.4125]], grad_fn=<AddmmBackward0>)
# tensor([[ 1.5694, -1.3895],
#         [ 1.3373, -1.2163]], grad_fn=<AddmmBackward0>)
